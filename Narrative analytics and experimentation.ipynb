# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns 
# %matplotlib inline 
import scipy.stats as stats

# %%
airlinedf=pd.read_csv('Airplane_Crashes_and_Fatalities_Since_1908.csv')

# %%
print(airlinedf.head())
airlinedf.tail()
# Out:
#          Date   Time                            Location  \
# 0  09/17/1908  17:18                 Fort Myer, Virginia
# 1  07/12/1912  06:30             AtlantiCity, New Jersey
# 2  08/06/1913    NaN  Victoria, British Columbia, Canada
# 3  09/09/1913  18:30                  Over the North Sea
# 4  10/17/1913  10:30          Near Johannisthal, Germany
#
#                  Operator Flight #          Route                    Type  \
# 0    Military - U.S. Army      NaN  Demonstration        Wright Flyer III
# 1    Military - U.S. Navy      NaN    Test flight               Dirigible
# 2                 Private        -            NaN        Curtiss seaplane
# 3  Military - German Navy      NaN            NaN  Zeppelin L-1 (airship)
# 4  Military - German Navy      NaN            NaN  Zeppelin L-2 (airship)
#
#   Registration cn/In  Aboard  Fatalities  Ground  \
# 0          NaN     1     2.0         1.0     0.0
# 1          NaN   NaN     5.0         5.0     0.0
# ...

# %%
airlinedf.describe()
# Out:
#             Aboard   Fatalities       Ground
# count  5246.000000  5256.000000  5246.000000
# mean     27.554518    20.068303     1.608845
# std      43.076711    33.199952    53.987827
# min       0.000000     0.000000     0.000000
# 25%       5.000000     3.000000     0.000000
# 50%      13.000000     9.000000     0.000000
# 75%      30.000000    23.000000     0.000000
# max     644.000000   583.000000  2750.000000

# %%
plt.figure()
airlinedf.plot()

# %%
airlinedf['incidents_85_99'].plot()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /anaconda3/envs/thinkful/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'incidents_85_99'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-39-7f600a876e16> in <module>
# ...

# %%
airlinedf.describe().plot()

# %%
airlinedf.fatalities_00_14.value_counts()
# Out:
# 0      32
# 1       2
# 88      2
# 109     1
# 110     1
# 46      1
# 3       1
# 7       1
# 14      1
# 143     1
# 337     1
# 83      1
# 84      1
# 22      1
# 23      1
# 51      1
# 537     1
# 283     1
# 92      1
# 158     1
# 416     1
# 225     1
# 188     1
# Name: fatalities_00_14, dtype: int64

# %%
planetypes=airlinedf['Type'].unique()

# %%
len(planetypes)
# Out:
# 2447

# %%
survivor= airlinedf[['Aboard','Fatalities']].sort_values('Aboard',ascending=[False])
survivorna=survivor.dropna(how='any')
survivorna
# Out:
#       Aboard  Fatalities
# 2963   644.0       583.0
# 3568   524.0       520.0
# 4645   517.0         1.0
# 3378   394.0        50.0
# 4536   393.0         1.0
# 3640   384.0        16.0
# 3829   356.0         9.0
# 4455   349.0       349.0
# 2726   346.0       346.0
# 4154   340.0        56.0
# 2813   330.0       155.0
# 3562   329.0       329.0
# 4651   315.0         3.0
# 4681   314.0        16.0
# 5057   309.0         0.0
# 4797   304.0         0.0
# 3240   301.0       301.0
# 3855   298.0       112.0
# 2720   298.0         1.0
# 4717   298.0         1.0
# 4302   293.0         1.0
# 4117   292.0         0.0
# 3238   291.0         2.0
# 3775   290.0       290.0
# 4423   275.0         3.0
# 4916   275.0       275.0
# 3541   274.0         0.0
# 3137   271.0       271.0
# 4249   271.0       264.0
# 3436   269.0       269.0
# ...      ...         ...
# 146      1.0         1.0
# 149      1.0         1.0
# 411      1.0         1.0
# 4358     1.0         1.0
# 456      1.0         1.0
# ...

# %% [markdown]
# # Problem:
# Smaller planes crash more often than larger planes. To provide more safty for customers, we should build bigger planes.
# ## Hypthosis:
# Are smaller planes more likely to crash when traveling
# Success matrix: larger planes are less likly to crash when flying.
# Secondary matrix: Do smaller planes have more fatalties than bigger planes when crashed.
#
# ## Rollout plan:
# We will computer simulate 1000 flights over 4 weeks of time, simulating different extreme weather conditions and different lengths of flights, to see which planes are more likely to crash. There will be three categories for plane sizes. Large planes: will hold 250 passangers or more. Medium planes: Will hold from 50 passangers to 249 passangers. Small planes: Will hold 49 passangers or less. For the first two weeks we will roll out mild flight conditions and short flight trips(in Miles). The second two weeks, we will implement harsh weather conditions and longer miles.
#
# For this expeirment success will if smaller planes crash more frequently than larger planes as well as if in those crashes the larger planes have fewer fatalties.
